# %%
import pandas as pd

# %%
researchDf = pd.read_csv('data/researchDf.csv')
# Out:
# C:\Users\12427\AppData\Local\Temp\ipykernel_12308\2599536906.py:1: DtypeWarning: Columns (218) have mixed types. Specify dtype option on import or set low_memory=False.
#   researchDf = pd.read_csv('data/researchDf.csv')

# %%
researchDf
# Out:
#                             person  adb_id Sun_sign Sun_dignity Sun_element  \
# 0      Annette von Droste-Hülshoff      24       cp   peregrine       earth
# 1      Annette von Droste-Hülshoff      24       cp   peregrine       earth
# 2             James Russell Lowell      31       pi   peregrine       water
# 3             James Russell Lowell      31       pi   peregrine       water
# 4             James Russell Lowell      31       pi   peregrine       water
# ...                            ...     ...      ...         ...         ...
# 62340              Raychelle Burks   94699       ar  Exaltation        fire
# 62341              Raychelle Burks   94699       ar  Exaltation        fire
# 62342                 Julie Aleman   94705       li        Fall         air
# 62343                 Julie Aleman   94705       li        Fall         air
# 62344                 Julie Aleman   94705       li        Fall         air
#
# ...

# %%
for name, df in researchDf.groupby("category"):
    print(name)
# Out:
# Diagnoses
# Family
# Lifestyle
# Mundane
# Notable
# Passions
# Personal
# Traits
# Vocation

# %%
df
# Out:
#                             person  adb_id Sun_sign Sun_dignity Sun_element  \
# 0      Annette von Droste-Hülshoff      24       cp   peregrine       earth
# 1      Annette von Droste-Hülshoff      24       cp   peregrine       earth
# 2             James Russell Lowell      31       pi   peregrine       water
# 3             James Russell Lowell      31       pi   peregrine       water
# 5                   Anton Bruckner      32       vi   peregrine       earth
# ...                            ...     ...      ...         ...         ...
# 62339              Raychelle Burks   94699       ar  Exaltation        fire
# 62340              Raychelle Burks   94699       ar  Exaltation        fire
# 62342                 Julie Aleman   94705       li        Fall         air
# 62343                 Julie Aleman   94705       li        Fall         air
# 62344                 Julie Aleman   94705       li        Fall         air
#
# ...

# %%
test = df[~df['person'].duplicated()]

# %%
test['Mercury_house'].value_counts()
# Out:
# house11    2917
# house10    2850
# house12    2797
# house2     2670
# house1     2667
# house3     2589
# house9     2568
# house4     2387
# house8     2244
# house5     2167
# house7     2158
# house6     2127
# Name: Mercury_house, dtype: int64

# %%
mystr = 'ab ab <script src="../../build/astrochart.js"></script>'
# Out:
#   Input In [4]
#     mystr = "ab ab <script src="../../build/astrochart.js"></script>"
#                                  ^
# SyntaxError: invalid syntax

# %%
mystr.find('ab')
# Out:
# 0
